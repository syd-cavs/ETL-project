# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Store CSV 1 into Data Frame and Clean up the Data

# %%
csv_file_1 = "Resources/games_data.csv"
games_df = pd.read_csv(csv_file_1)
games_df.head()
# Out:
#    Unnamed: 0                             game  score  leaderbord  gamers  \
# 0           0               A Boy and His Blob    638        2.02    2194
# 1           1                    A Hat in Time   1992        1.53    7062
# 2           2              A Hero and a Garden   1364        1.01     503
# 3           3         A Hero and a Garden (EU)   1363        1.01     581
# 4           4  A King's Tale: Final Fantasy XV    637        2.02   21914
#
#    comp_perc  rating                                                url  \
# 0       16.5     3.2  https://www.truetrophies.com/game/A-Boy-and-Hi...
# 1       35.9     4.2  https://www.truetrophies.com/game/A-Hat-in-Tim...
# 2       97.6     5.0  https://www.truetrophies.com/game/A-Hero-and-a...
# 3       97.8     2.9  https://www.truetrophies.com/game/A-Hero-and-a...
# 4       14.1     3.3  https://www.truetrophies.com/game/A-Kings-Tale...
#
#    min_comp_time  max_comp_time
# 0             15             20
# 1             15             20
# 2              0              1
# 3              0              1
# 4              4              5

# %%
cleaned_games_df = games_df[["game", "score", "gamers", "comp_perc", "rating", "min_comp_time", "max_comp_time"]]
cleaned_games_df
# Out:
#                                  game  score  gamers  comp_perc  rating  \
# 0                  A Boy and His Blob    638    2194       16.5     3.2
# 1                       A Hat in Time   1992    7062       35.9     4.2
# 2                 A Hero and a Garden   1364     503       97.6     5.0
# 3            A Hero and a Garden (EU)   1363     581       97.8     2.9
# 4     A King's Tale: Final Fantasy XV    637   21914       14.1     3.3
# ...                               ...    ...     ...        ...     ...
# 1579         36 Fragments of Midnight   1367    8472       82.3     2.5
# 1580  36 Fragments of Midnight (Asia)   1335    2131       88.9     2.4
# 1581    36 Fragments of Midnight (EU)   1382   12273       79.2     2.4
# 1582            428: Shibuya Scramble   1943     916       41.5     4.2
# 1583       428: Shibuya Scramble (EU)   1917     718       42.6     4.2
#
#       min_comp_time  max_comp_time
# 0                15             20
# 1                15             20
# 2                 0              1
# 3                 0              1
# 4                 4              5
# ...             ...            ...
# 1579              0              1
# 1580              0              1
# 1581              0              1
# 1582             40             50
# 1583             40             50
#
# [1584 rows x 7 columns]

# %%
renamed_games_df = cleaned_games_df.rename(columns={   
       "comp_perc": "completion_percentage",
       "min_comp_time": "minimum_completion_time",
       "max_comp_time": "maximum_completion_time"})
renamed_games_df
# Out:
#                                  Game  Score  Gamers  Completion_Percentage  \
# 0                  A Boy and His Blob    638    2194                   16.5
# 1                       A Hat in Time   1992    7062                   35.9
# 2                 A Hero and a Garden   1364     503                   97.6
# 3            A Hero and a Garden (EU)   1363     581                   97.8
# 4     A King's Tale: Final Fantasy XV    637   21914                   14.1
# ...                               ...    ...     ...                    ...
# 1579         36 Fragments of Midnight   1367    8472                   82.3
# 1580  36 Fragments of Midnight (Asia)   1335    2131                   88.9
# 1581    36 Fragments of Midnight (EU)   1382   12273                   79.2
# 1582            428: Shibuya Scramble   1943     916                   41.5
# 1583       428: Shibuya Scramble (EU)   1917     718                   42.6
#
#       Rating  Minimum_Completion_Time  Maximum_Completion_Time
# 0        3.2                       15                       20
# 1        4.2                       15                       20
# 2        5.0                        0                        1
# 3        2.9                        0                        1
# 4        3.3                        4                        5
# ...      ...                      ...                      ...
# 1579     2.5                        0                        1
# 1580     2.4                        0                        1
# 1581     2.4                        0                        1
# 1582     4.2                       40                       50
# 1583     4.2                       40                       50
#
# [1584 rows x 7 columns]

# %% [markdown]
# # Store CSV 2 into Data Frame and Clean up the Data

# %%
csv_file_2 = "Resources/PS4_GamesSales.csv"
sales_df = pd.read_csv(csv_file_2, header=0, encoding='unicode_escape')
sales_df.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
cleaned_sales_df = sales_df[["Game", "Year", "Genre", "Publisher", "North America", "Global"]]
renamed_sales_df = cleaned_sales_df.rename(columns={
    "Game": "game", "Year": "year", "Genre": "genre",
    "Publisher": "publisher", 
    "North America": "north_america", "Global": "global"})
renamed_sales_df
# Out:
#                                     Game    Year             Genre  \
# 0                     Grand Theft Auto V  2014.0            Action
# 1              Call of Duty: Black Ops 3  2015.0           Shooter
# 2                  Red Dead Redemption 2  2018.0  Action-Adventure
# 3                     Call of Duty: WWII  2017.0           Shooter
# 4                                FIFA 18  2017.0            Sports
# ...                                  ...     ...               ...
# 1029  Fallen Legion: Flames of Rebellion     NaN      Role-Playing
# 1030            Radial G Racing Revolved  2017.0            Racing
# 1031                The Mummy Demastered     NaN            Action
# 1032          Project Nimbus: Code Mirai     NaN            Action
# 1033                 Battle Chef Brigade     NaN            Action
#
#            Publisher  North_America  Global
# 0     Rockstar Games           6.06   19.39
# 1         Activision           6.18   15.09
# 2     Rockstar Games           5.26   13.94
# 3         Activision           4.67   13.40
# 4          EA Sports           1.27   11.80
# ...              ...            ...     ...
# 1029             NaN           0.00    0.00
# 1030   Tammeka Games           0.00    0.00
# 1031             NaN           0.00    0.00
# 1032             NaN           0.00    0.00
# 1033             NaN           0.00    0.00
#
# [1034 rows x 6 columns]

# %% [markdown]
# # Combine the data in Pandas to see if how many videogames appear in each data set

# %%
combined_df = pd.merge(renamed_sales_df, renamed_games_df, how="inner")
new_combined_df = combined_df.drop(index=188)
new_combined_df
# Out:
#                      Game    Year             Genre  \
# 0      Grand Theft Auto V  2014.0            Action
# 1      Call of Duty: WWII  2017.0           Shooter
# 2                 FIFA 18  2017.0            Sports
# 3                 FIFA 17  2016.0            Sports
# 4               Fallout 4  2015.0      Role-Playing
# ..                    ...     ...               ...
# 243             Days Gone  2019.0  Action-Adventure
# 244          Metro Exodus  2019.0           Shooter
# 245                Anthem  2019.0      Role-Playing
# 246      Chaos on Deponia  2017.0         Adventure
# 247  The Mummy Demastered     NaN            Action
#
#                           Publisher  North_America  Global  Score  Gamers  \
# 0                    Rockstar Games           6.06   19.39   5913  231535
# 1                        Activision           4.67   13.40   7360  154762
# 2                         EA Sports           1.27   11.80   3098   67123
# 3                   Electronic Arts           1.26   10.94   3370   69911
# 4                Bethesda Softworks           2.91    8.48   3311  170083
# ..                              ...            ...     ...    ...     ...
# 243  Sony Interactive Entertainment           0.00    0.00   4788  121982
# 244                     Deep Silver           0.00    0.00   3820   34285
# 245                 Electronic Arts           0.00    0.00   3133   46185
# 246          Daedalic Entertainment           0.00    0.00   1500    1074
# 247                             NaN           0.00    0.00   1944    1889
#
#      Completion_Percentage  Rating  Minimum_Completion_Time  \
# 0                      0.4     4.5                      200
# 1                      0.6     3.6                       35
# 2                      6.1     3.6                       40
# 3                      4.3     3.7                       50
# 4                      3.5     4.2                       60
# ..                     ...     ...                      ...
# 243                    1.1     4.2                       60
# 244                    2.5     3.9                       20
# 245                    6.9     3.0                       50
# 246                   77.6     3.3                        3
# 247                   35.5     3.9                        6
#
#      Maximum_Completion_Time
# 0                        700
# 1                         40
# 2                         50
# 3                         60
# 4                         80
# ..                       ...
# 243                       80
# 244                       25
# 245                       60
# 246                        4
# 247                        8
#
# [247 rows x 12 columns]

# %%
new_combined_df.to_csv("cleaned_combined_data.csv", index = False)

# %% [markdown]
# # Extract Original Tables from Cleaned Combined Data

# %%
new_games_df = new_combined_df[['game', 'score', 'gamers', 
                            'completion_percentage', 'rating', 'minimum_completion_time',
                            'maximum_completion_time']]
new_games_df
# Out:
#                      Game  Score  Gamers  Completion_Percentage  Rating  \
# 0      Grand Theft Auto V   5913  231535                    0.4     4.5
# 1      Call of Duty: WWII   7360  154762                    0.6     3.6
# 2                 FIFA 18   3098   67123                    6.1     3.6
# 3                 FIFA 17   3370   69911                    4.3     3.7
# 4               Fallout 4   3311  170083                    3.5     4.2
# ..                    ...    ...     ...                    ...     ...
# 243             Days Gone   4788  121982                    1.1     4.2
# 244          Metro Exodus   3820   34285                    2.5     3.9
# 245                Anthem   3133   46185                    6.9     3.0
# 246      Chaos on Deponia   1500    1074                   77.6     3.3
# 247  The Mummy Demastered   1944    1889                   35.5     3.9
#
#      Minimum_Completion_Time  Maximum_Completion_Time
# 0                        200                      700
# 1                         35                       40
# 2                         40                       50
# 3                         50                       60
# 4                         60                       80
# ..                       ...                      ...
# 243                       60                       80
# 244                       20                       25
# 245                       50                       60
# 246                        3                        4
# 247                        6                        8
#
# [247 rows x 7 columns]

# %%
new_games_df.to_csv("cleaned_games_data.csv", index = False)

# %%
new_sales_df = new_combined_df[["game", "year", "genre", "Publisher", "North_America", "Global"]]
new_sales_df
# Out:
#                      Game    Year             Genre  \
# 0      Grand Theft Auto V  2014.0            Action
# 1      Call of Duty: WWII  2017.0           Shooter
# 2                 FIFA 18  2017.0            Sports
# 3                 FIFA 17  2016.0            Sports
# 4               Fallout 4  2015.0      Role-Playing
# ..                    ...     ...               ...
# 243             Days Gone  2019.0  Action-Adventure
# 244          Metro Exodus  2019.0           Shooter
# 245                Anthem  2019.0      Role-Playing
# 246      Chaos on Deponia  2017.0         Adventure
# 247  The Mummy Demastered     NaN            Action
#
#                           Publisher  North_America  Global
# 0                    Rockstar Games           6.06   19.39
# 1                        Activision           4.67   13.40
# 2                         EA Sports           1.27   11.80
# 3                   Electronic Arts           1.26   10.94
# 4                Bethesda Softworks           2.91    8.48
# ..                              ...            ...     ...
# 243  Sony Interactive Entertainment           0.00    0.00
# 244                     Deep Silver           0.00    0.00
# 245                 Electronic Arts           0.00    0.00
# 246          Daedalic Entertainment           0.00    0.00
# 247                             NaN           0.00    0.00
#
# [247 rows x 6 columns]

# %%
new_sales_df.to_csv("cleaned_sales_data.csv", index = False)

# %% [markdown]
# # Connect to local database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/videogames"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['ps4games', 'sales_data']

# %%
new_games_df.to_sql(name='ps4games', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Game" of relation "ps4games" does not exist
# LINE 1: INSERT INTO ps4games ("Game", "Score", "Gamers", "Completion...
#                               ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-17-59cac233f83e> in <module>
# ----> 1 new_games_df.to_sql(name='ps4games', con=engine, if_exists='append', index=False)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1131             distilled_params,
#    1132             compiled_sql,
# -> 1133             distilled_params,
#    1134         )
#    1135         if self._has_events or self.engine._has_events:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1316         except BaseException as e:
#    1317             self._handle_dbapi_exception(
# -> 1318                 e, statement, parameters, cursor, context
#    1319             )
#    1320
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1510             elif should_wrap:
#    1511                 util.raise_(
# -> 1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#    1514             else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#    1260             elif not parameters and context.no_parameters:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "Game" of relation "ps4games" does not exist
# LINE 1: INSERT INTO ps4games ("Game", "Score", "Gamers", "Completion...
#                               ^
#
# [SQL: INSERT INTO ps4games ("Game", "Score", "Gamers", "Completion_Percentage", "Rating", "Minimum_Completion_Time", "Maximum_Completion_Time") VALUES (%(Game)s, %(Score)s, %(Gamers)s, %(Completion_Percentage)s, %(Rating)s, %(Minimum_Completion_Time)s, %(Maximum_Completion_Time)s)]
# [parameters: ({'Game': 'Grand Theft Auto V', 'Score': 5913, 'Gamers': 231535, 'Completion_Percentage': 0.4, 'Rating': 4.5, 'Minimum_Completion_Time': 200, 'Maximum_Completion_Time': 700}, {'Game': 'Call of Duty: WWII', 'Score': 7360, 'Gamers': 154762, 'Completion_Percentage': 0.6, 'Rating': 3.6, 'Minimum_Completion_Time': 35, 'Maximum_Completion_Time': 40}, {'Game': 'FIFA 18', 'Score': 3098, 'Gamers': 67123, 'Completion_Percentage': 6.1, 'Rating': 3.6, 'Minimum_Completion_Time': 40, 'Maximum_Completion_Time': 50}, {'Game': 'FIFA 17', 'Score': 3370, 'Gamers': 69911, 'Completion_Percentage': 4.3, 'Rating': 3.7, 'Minimum_Completion_Time': 50, 'Maximum_Completion_Time': 60}, {'Game': 'Fallout 4', 'Score': 3311, 'Gamers': 170083, 'Completion_Percentage': 3.5, 'Rating': 4.2, 'Minimum_Completion_Time': 60, 'Maximum_Completion_Time': 80}, {'Game': 'FIFA 16', 'Score': 3177, 'Gamers': 67700, 'Completion_Percentage': 5.1, 'Rating': 3.8, 'Minimum_Completion_Time': 35, 'Maximum_Completion_Time': 40}, {'Game': 'Call of Duty: Advanced Warfare', 'Score': 4896, 'Gamers': 109190, 'Completion_Percentage': 0.8, 'Rating': 3.6, 'Minimum_Completion_Time': 20, 'Maximum_Completion_Time': 25}, {'Game': 'Battlefield 1', 'Score': 4515, 'Gamers': 145216, 'Completion_Percentage': 2.0, 'Rating': 4.2, 'Minimum_Completion_Time': 35, 'Maximum_Completion_Time': 40}  ... displaying 10 of 247 total bound parameter sets ...  {'Game': 'Chaos on Deponia', 'Score': 1500, 'Gamers': 1074, 'Completion_Percentage': 77.6, 'Rating': 3.3, 'Minimum_Completion_Time': 3, 'Maximum_Completion_Time': 4}, {'Game': 'The Mummy Demastered', 'Score': 1944, 'Gamers': 1889, 'Completion_Percentage': 35.5, 'Rating': 3.9, 'Minimum_Completion_Time': 6, 'Maximum_Completion_Time': 8})]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
new_sales_df.to_sql(name='sales_data', con=engine, if_exists='append', index=False)
